# %% [markdown]
# import requests
#
# from shapely.geometry import mapping, shape
# from shapely.prepared import prep
# from shapely.geometry import Point
#
#
# #data = requests.get("https://raw.githubusercontent.com/datasets/geo-countries/master/data/countries.geojson").json()
#
# countries = {}
# for feature in data["features"]:
#     geom = feature["geometry"]
#     country = feature["properties"]["ADMIN"]
#     countries[country] = prep(shape(geom))
#
# print(len(countries))
#
# def get_country(lon, lat):
#     point = Point(lon, lat)
#     for country, geom in countries.iteritems():
#         if geom.contains(point):
#             return country
#
#     return "unknown"
# print(get_country(10.0, 47.0))

# %%
#https://maps.googleapis.com/maps/api/geocode/outputFormat?parameters

# %% [markdown]
# from geopy.geocoders import Nominatim
# #geolocator = Nominatim(user_agent="https://nominatim.openstreetmap.org/search?q=<postalcodes>")
#
# # Latitude & Longitude input
# coordinates = "17.3850 , 78.4867"
#
# location = geolocator.reverse(coordinates)
#
# address = location.raw['address']
#
# # Traverse the data
# city = address.get('city', '')
# state = address.get('state', '')
# country = address.get('country', '')
# #https://nominatim.openstreetmap.org/search?<params>
# #city
# state
# country

# %%
import pandas as pd
data = pd.read_csv('C:/Users/Ajiri/Downloads/cleaned_data.csv')
data
# Out:
# C:\Users\Ajiri\AppData\Local\Temp\ipykernel_21832\416720241.py:2: DtypeWarning: Columns (0,2,37,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('C:/Users/Ajiri/Downloads/cleaned_data.csv')
#        accident_index  accident_year_x accident_reference_x  \
# 0       2021010287148             2021             10287148
# 1       2021010287148             2021             10287148
# 2       2021010287148             2021             10287148
# 3       2021010287149             2021             10287149
# 4       2021010287149             2021             10287149
# ...               ...              ...                  ...
# 155413  2021991047985             2021            991047985
# 155414  2021991047985             2021            991047985
# 155415  2021991048010             2021            991048010
# 155416  2021991048010             2021            991048010
# 155417  2021991048011             2021            991048011
#
# ...

# %% [markdown]
# from geopy.geocoders import Nominatim
# #geolocator = Nominatim(user_agent="https://nominatim.openstreetmap.org/search?q=<postalcodes>")
#
# # Latitude & Longitude input
# coordinates = data['latitude'], ['longitude']
#
# location = geolocator.reverse(coordinates)
#
# address = location.raw['address']
#
# # Traverse the data
# city = address.get('city', '')
# state = address.get('state', '')
# country = address.get('country', '')
# #https://nominatim.openstreetmap.org/search?<params>
# city
# #state
# #country

# %%
from geopy.geocoders import Nominatim
#geolocator = Nominatim(user_agent="https://nominatim.openstreetmap.org/search?q=<postalcodes>")

# Latitude & Longitude input
#item1 = data['latitude']
#item2 = data['longitude']
coordinates = "51.623425, -0.246102"
#5.15212291e+01 -8.21582084e-03
location = geolocator.reverse(coordinates)

address = location.raw['address']

# Traverse the data
city = address.get('city', '')
state = address.get('state', '')
country = address.get('country', '')
 
#data['animal2'] = data.apply(city, axis='columns')
#https://nominatim.openstreetmap.org/search?<params>
city
#state
#country
# Out:
# 'London'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155418 entries, 0 to 155417
# Data columns (total 81 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   accident_index                               155418 non-null  object
#  1   accident_year_x                              155418 non-null  int64
#  2   accident_reference_x                         155418 non-null  object
#  3   location_easting_osgr                        155418 non-null  float64
#  4   location_northing_osgr                       155418 non-null  float64
#  5   longitude                                    155418 non-null  float64
#  6   latitude                                     155418 non-null  float64
#  7   police_force                                 155418 non-null  int64
#  8   accident_severity                            155418 non-null  int64
# ...

# %%
data['accident_severity'].value_counts()/data.shape[0]*100
# Out:
# 3    77.528343
# 2    20.577411
# 1     1.894246
# Name: accident_severity, dtype: float64

# %%
#trying to get areas that has most numbers of accident
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

from sklearn.cluster import KMeans
#from matplotlib.colors import LinearSegmentedColormap
data.plot(kind = "scatter", x = "longitude", y = "latitude", alpha = 0.5,
             s = data["number_of_casualties"]/100, label = "number_of_casualties", figsize=(15,5),
             c = "accident_severity", cmap = 'turbo', colorbar= True)
plt.legend()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

from sklearn.cluster import KMeans
x=data.loc[:, ['latitude', 'longitude']]
kmeans = KMeans(n_clusters=30)
kmeans = kmeans.fit(x)
labels = kmeans.labels_
data['cluster'] = labels
plt.scatter(x['latitude'], x['longitude'], s=50, c=labels, marker='.',\
            cmap=plt.cm.get_cmap('jet', 30))
plt.colorbar()
plt.show()
centers = kmeans.cluster_centers_
counts = np.bincount(labels)
result = np.where(counts == np.amax(counts))
result = result[0]
print(result)
most_accidents = centers[result]
f = result.item(0) # get the int of the cluster number
print(centers[f])
print(counts, f)
# Out:
# [23]
# [ 5.15212291e+01 -8.21582084e-03]
# [17234  5555  5110  1340  5193  3070  4747  5170 14242  3731  2857  9668
#   4386  2823  3041  8515  1935  2813  3613  3011   295  3785  9606 19197
#   1074  2556  3811  1854  3827  1359] 23

# %%
import pandas as pd
import matplotlib.pyplot as plt
x= data[['latitude','longitude']]
plt.scatter(x['latitude'], x['longitude'], cmap='viridis')
plt.colorbar()
plt.show()
# Out:
# C:\Users\Ajiri\AppData\Local\Temp\ipykernel_21832\526204997.py:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x['latitude'], x['longitude'], cmap='viridis')

# %% [markdown]
# import pandas as pd
# import io
# from geopy.geocoders import Nominatim
# geolocator = Nominatim(user_agent="geoapiExercises")
#
# s = """Latitude   Longitude
# 42.022506  -88.168156
# 41.877445  -87.723846
# 29.986801  -90.166314"""
#
# #df = pd.read_csv(io.StringIO(s), delim_whitespace=True)
#
# def city_state_country(row):
#     coord = f"{row['latitude']}, {row['longitude']}"
#     location = geolocator.reverse(coord, exactly_one=True)
#     address = location.raw['address']
#     city = address.get('city', '')
#     state = address.get('state', '')
#     country = address.get('country', '')
#     row['city'] = city
#     row['state'] = state
#     row['country'] = country
#     return row
#
# df = data.apply(city_state_country, axis=1)
# print(df)

# %%
import pandas as pd
import io
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent=" https://nominatim.openstreetmap.org/search?q=<city-county-country>")

#s = """Latitude   Longitude  
#42.022506  -88.168156  
#41.877445  -87.723846  
#29.986801  -90.166314"""

#df = pd.read_csv(io.StringIO(s), delim_whitespace=True)

def city_county_country(row):
    coord = f"{row['latitude']}, {row['longitude']}"
    location = geolocator.reverse(coord, exactly_one=True)
    address = location.raw['address']
    city = address.get('city', '')
    state = address.get('county', '')
    country = address.get('country', '')
    row['city'] = city
    row['county'] = state
    row['country'] = country
    return row

df = data.apply(city_state_country, axis=1)
print(df)

# %%
#data.info()

# %%
import pandas as pd 
import folium
lat = data['latitude']
long = data['longitude']
locate = data[['latitude', 'longitude']]
map = folium.Map(location=[locate.latitude.mean(), locate.longitude.mean()], zoom_start=14, control_scale=True)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd 
import folium
lat = data['latitude']
long = data['longitude']
locate = data[['latitude', 'longitude']]
map = folium.Map(location=[locate.latitude.mean(), locate.longitude.mean()], zoom_start=14, control_scale=True)
map
location_info = locate.iterrows()
folium.Marker([location_info['latitude'], location_info['longitude']]), popup==location_info.add_to(map)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [154], line 9
#       7 map
#       8 location_info = locate.iterrows()
# ----> 9 folium.Marker([location_info['latitude'], location_info['longitude']]), popup==location_info.add_to(map)
#
# TypeError: 'generator' object is not subscriptable
